# %% [markdown]
# Question 6
# Create a line plot showing the number of marriages and divorces per capita in the
# U.S. between 1867 and 2014. Label both lines and show the legend.
# Don't forget to label your axes!

# %%
import pandas as pd
import matplotlib.pyplot as plt
data=pd.read_csv("C:/Users/HP/Downloads/us-marriages-divorces-1867-2014.csv")
data.plot(x='Year', y=['Marriages', 'Divorces'], figsize=(10, 6), linewidth=2)

# Adding labels and title
plt.xlabel('Year')
plt.ylabel('Number per Capita')
plt.title('Number of Marriages and Divorces per Capita in the U.S. (1867-2014)')

# Showing legend
plt.legend(['Marriages', 'Divorces'])

# Show the plot
plt.grid(True)
plt.show()

# %% [markdown]
# Question 7
# Create a vertical bar chart comparing the number of marriages and divorces per
# capita in the U.S. between 1900, 1950, and 2000.
# Don't forget to label your axes!

# %%
import pandas as pd
import matplotlib.pyplot as plt
file_path = r'C:\Users\HP\Downloads\us-marriages-divorces-1867-2014.csv'
data = pd.read_csv(file_path)

# Filter data for the required years (1900, 1950, 2000)
years = [1900, 1950, 2000]
filtered_data = data[data['Year'].isin(years)]

marriages = filtered_data[filtered_data['Year'] == 1900]['Marriages'].values[0], \
            filtered_data[filtered_data['Year'] == 1950]['Marriages'].values[0], \
            filtered_data[filtered_data['Year'] == 2000]['Marriages'].values[0]

divorces = filtered_data[filtered_data['Year'] == 1900]['Divorces'].values[0], \
           filtered_data[filtered_data['Year'] == 1950]['Divorces'].values[0], \
           filtered_data[filtered_data['Year'] == 2000]['Divorces'].values[0]

# Plotting the vertical bar chart
bar_width = 0.35
index = range(len(years))

plt.bar(index, marriages, bar_width, label='Marriages')
plt.bar([i + bar_width for i in index], divorces, bar_width, label='Divorces')

# Adding labels and title
plt.xlabel('Year')
plt.ylabel('Number per Capita')
plt.title('Number of Marriages and Divorces per Capita in the U.S.')
plt.xticks([i + bar_width / 2 for i in index], years)
plt.legend()

# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# Question 8
# Create a horizontal bar chart that compares the deadliest actors in Hollywood. Sort
# the actors by their kill count and label each bar with the corresponding actor's name.
# Don't forget to label your axes!

# %%
import pandas as pd
import matplotlib.pyplot as plt

file_path = r'C:\Users\HP\Downloads\actor_kill_counts.csv'
data = pd.read_csv(file_path)

sorted_data = data.sort_values(by='Count', ascending=True)

plt.figure(figsize=(10, 6))
plt.barh(sorted_data['Actor'], sorted_data['Count'], color='orange')

# Adding labels and title
plt.xlabel('Kill Count')
plt.ylabel('Actor')
plt.title('Deadliest Actors in Hollywood by Kill Count')

# Label each bar
for index, value in enumerate(sorted_data['Count']):
    plt.text(value, index, str(value))

# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# Question 9
# Create a pie chart showing the fraction of all Roman Emperors that were
# assassinated.
# Make sure that the pie chart is an even circle, labels the categories, and shows the
# percentage breakdown of the categories.

# %%
import pandas as pd
import matplotlib.pyplot as plt

file_path = r'C:\Users\HP\Downloads\roman-emperor-reigns.csv'
data = pd.read_csv(file_path)
assassination_count = data['Cause_of_Death'].str.contains('assassinat', case=False).sum()

total_emperors = len(data)
fraction_assassinated = assassination_count / total_emperors
fraction_not_assassinated = 1 - fraction_assassinated

# Create labels
labels = ['Assassinated', 'Not Assassinated']
sizes = [fraction_assassinated, fraction_not_assassinated]
plt.figure(figsize=(8, 8))
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=140)
plt.axis('equal')
plt.title('Fraction of Roman Emperors Assassinated')

# Show the plot
plt.show()

# %% [markdown]
# Question 10
# Create a scatter plot showing the relationship between the total revenue earned by
# arcades and the number of Computer Science PhDs awarded in the U.S. between
# 2000 and 2009.
# Don't forget to label your axes!
# Color each dot according to its year

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
 
# Load the data from the CSV file
file_path = 'C:/Users/hp/Downloads/arcade-revenue-vs-cs-doctorates.csv'
data = pd.read_csv(file_path)
 
# Plotting
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Total Arcade Revenue (billions)', y='Computer Science Doctorates Awarded (US)', hue='Year', data=data, palette='viridis')
 
# Adding labels and title
plt.xlabel('Total Arcade Revenue (billions)')
plt.ylabel('Number of Computer Science PhDs Awarded (US)')
plt.title('Relationship between Arcade Revenue and CS PhDs (2000-2009)')
 
# Display the plot
plt.legend(title='Year')
plt.show()
